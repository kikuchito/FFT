# %%
import numpy as np
import pandas as pd
data = []
with open("E:/vivado/vivado_proj/FFT/mem_in.txt") as f:
    for line in f:
        data.append([int(x) for x in line.split()])
data = np.array(data)

def binaryToDecimal(binary):
 
    decimal, i = 0, 0
    while(binary != 0):
        if i == 24 and dec == 1:
            decimal = decimal * -1
        elif i == 24 and dec == 0:
            decimal = decimal * 1
        dec = binary % 10
        decimal = decimal + dec * pow(2, i)
        binary = binary//10
        i += 1
        
    return decimal
    
# def binaryToDecimal1(binary):
#     num = binary
#     for j in range (num):
#         decimal, i = 0, 0
#         dec = binary % 10
#         decimal = decimal + dec * pow(2, i)
#         binary = binary//10
#         i += 1
#     return decimal

print(data)

i0 = data[0] % (10**25)
r0 = data[0] // (10**25)
zi0 = 0
zr0 = 0
if ((data[0] % (10**25))//10**24 == 1):
    zi0 = -1
else: 
    zi0 = 1
if ((data[0] // (10**25))//10**24 == 1):
    zr0 = -1
else: 
    zr0 = 1
i0 = binaryToDecimal(i0) * zi0
r0 = binaryToDecimal(r0) * zr0
print(r0, i0)


i1 = data[1] % (10**25)
r1 = data[1] // (10**25)
zi1 = 0
zr1 = 0
if ((data[1] % (10**25))//10**24 == 1):
    zi1 = -1
else: 
    zi1 = 1
if ((data[1] // (10**25))//10**24 == 1):
    zr1 = -1
else: 
    zr1 = 1
i1 = binaryToDecimal(i1) * zi1
r1 = binaryToDecimal(r1) * zr1
print(r1, i1)

i2 = data[2] % (10**25)
r2 = data[2] // (10**25)
zi2 = 0
zr2 = 0
if ((data[2] % (10**25))//10**24 == 1):
    zi2 = -1
else: 
    zi2 = 1
if ((data[2] // (10**25))//10**24 == 1):
    zr2 = -1
else: 
    zr2 = 1
i2 = binaryToDecimal(i2) * zi2
r2 = binaryToDecimal(r2) * zr2
print(r2 , i2)

i3 = data[3] % (10**25)
r3 = data[3] // (10**25)
zi3 = 0
zr3 = 0
if ((data[3] % (10**25))//10**24 == 1):
    zi3 = -1
else: 
    zi3 = 1
if ((data[3] // (10**25))//10**24 == 1):
    zr3 = -1
else: 
    zr3 = 1
i3 = binaryToDecimal(i3) * zi3
r3 = binaryToDecimal(r3) * zr3
print(r3, i3)

i4 = data[4] % (10**25)
r4 = data[4] // (10**25)
zi4 = 0
zr4 = 0
if ((data[4] % (10**25))//10**24 == 1):
    zi4 = -1
else: 
    zi4 = 1
if ((data[4] // (10**25))//10**24 == 1):
    zr4 = -1
else: 
    zr4 = 1
i4 = binaryToDecimal(i4) * zi4
r4 = binaryToDecimal(r4) * zr4
print(r4, i4)

i5 = data[5] % (10**25)
r5 = data[5] // (10**25)
zi5 = 0
zr5 = 0
if ((data[5] % (10**25))//10**24 == 1):
    zi5 = -1
else: 
    zi5 = 1
if ((data[5] // (10**25))//10**24 == 1):
    zr5 = -1
else: 
    zr5 = 1
i5 = binaryToDecimal(i5) * zi5
r5 = binaryToDecimal(r5) * zr5
print(r5, i5)

i6 = data[6] % (10**25)
r6 = data[6] // (10**25)
zi6 = 0
zr6 = 0
if ((data[6] % (10**25))//10**24 == 1):
    zi6 = -1
else: 
    zi6 = 1
if ((data[6] // (10**25))//10**24 == 1):
    zr6 = -1
else: 
    zr6 = 1
i6 = binaryToDecimal(i6) * zi6
r6 = binaryToDecimal(r6) * zr6
print(r6, i6)

i7 = data[7] % (10**25)
r7 = data[7] // (10**25)
zi7 = 0
zr7 = 0
if ((data[7] % (10**25))//10**24 == 1):
    zi7 = -1
else: 
    zi7 = 1
if ((data[7] // (10**25))//10**24 == 1):
    zr7 = -1
else: 
    zr7 = 1
i7 = binaryToDecimal(i7) * zi7
r7 = binaryToDecimal(r7) * zr7
print(r7, i7)


stage = np.array(8, complex)
stage = np.array([r0 + i0*1j, r1 + i1*1j, r2 + i2*1j, r3 + i3*1j, r4 + i4*1j, r5 + i5*1j, r6 + i6*1j, r7 + i7*1j])

pd.DataFrame(stage).to_csv(r"E:/vivado/vivado_proj/FFT/py_mem.txt", header=None, index=False)
print(stage)

# f   = open("E:/vivado/vivado_proj/FFT/py_mem.txt",'w')
# f.write(str(stage))
# f.close()
# Out:
# [[10000000000000000000000001]
#  [100000000000000000000000001000000000]
#  [11111111111111111111111010000000000000000000000001]
#  [101111111111111111111111110]
#  [10000000000000000000000000]
#  [100000001111111111111111111100000]
#  [10000000000000000000000000]
#  [110000000000000000000000000]]
# [1] [1]
# [1024] [512]
# [-3] [1]
# [2] [-2]
# [1] 0
# [128] [-32]
# [1] 0
# [3] 0
# [[(1+1j)]
#  [(1024+512j)]
#  [(-3+1j)]
#  [(2-2j)]
#  [(1+0j)]
#  [(128-32j)]
#  [(1+0j)]
#  [(3+0j)]]
